# %%
# Configuração inicial
import psycopg2
import pandas as pd

# String de conexão compartilhada
CONN_STRING = "postgresql://externo.leitura:WdN#R10gX4@172.31.3.62:5432/fiscalize"

# Configurar opções de exibição do pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)

# %%
# Query: Demanda específica por ID
conn = psycopg2.connect(CONN_STRING)
cursor = conn.cursor()

query = "SELECT * FROM public.demanda WHERE id = 2754325;"
cursor.execute(query)

colnames = [desc[0] for desc in cursor.description]
rows = cursor.fetchall()

cursor.close()
conn.close()

df = pd.DataFrame(rows, columns=colnames)
df
# Out:
#         id  ativo        data_criacao assuntodemanda             bairro  \
# 0  2754325   True 2020-09-10 14:21:00           None  Conjunto Ceará II
#
#   complemento datahoraaberturademanda  datahoraocorrencia  \
# 0        None     2020-09-10 14:21:00 2020-09-10 14:10:00
#
#                                            descricao  enderecoproximidade  \
# 0  Som alto durante toda a semana, principalmente...                False
#
#      latitude logradouro longitude numero pontoreferencia      protocolo  \
# 0  -3.7735758    Rua 735  -38.6041    331          Nenhum  2009102754325
#
#    situacao demanda_id  fiscalizado_id  grupodemanda_id  pessoageradora_id  \
# 0         2       None         2754324            15472            1439029
#
#    regional_id os_id  requeracompanhamento trataranonimamente  plano_id  \
# 0           11  None                 False               None   7480385
#
#   usuarioalteracao autoverificacao demandareferencia situacaoanterior  \
# ...

# %%
# Query: Primeiras 5 pessoas
conn = psycopg2.connect(CONN_STRING)
cursor = conn.cursor()

query = "SELECT * FROM public.pessoa LIMIT 5;"
cursor.execute(query)

colnames = [desc[0] for desc in cursor.description]
rows = cursor.fetchall()

cursor.close()
conn.close()

df = pd.DataFrame(rows, columns=colnames)
df
# Out:
#         id  ativo            data_criacao         bairro complemento contato  \
# 0  6313059   True 2024-04-12 09:32:53.470       SIQUEIRA        None    None
# 1  6313071   True 2024-04-12 09:35:46.801  NÃO INFORMADO        None    None
# 2  6313070   True 2024-04-12 09:35:46.801    CIDADE 2000        None    None
# 3  6313114   True 2024-04-12 09:41:40.231        VARJOTA        None    None
# 4  6313175   True 2024-04-12 09:45:50.674  NÃO INFORMADO        None    None
#
#        cpfcnpj    latitude                  logradouro longitude nomefantasia  \
# 0  41618319353  -3.8048956                 RUA MIRACEL  -38.6307         None
# 1         None        None                                  None         None
# 2         None        None          ALAMEDA DOS LIRIOS      None         None
# 3  12792233753  -3.7344904  RUA CORONEL MANUEL JESUÍNO  -38.4847         None
# 4         None        None                                  None         None
#
# ...

# %%
# Query: Demandas do usuário 12201
conn = psycopg2.connect(CONN_STRING)
cursor = conn.cursor()

query = """
SELECT d.protocolo, d.os_direta
FROM demanda d 
LEFT JOIN fiscaldemanda fd ON d.id = fd.demanda_id AND fd.ativo = TRUE
WHERE fd.usuario_id = 12201
AND d.ativo = TRUE
AND (d.os_direta = FALSE OR d.os_direta IS NULL)
AND d.situacao IN (2,11,12)
"""
cursor.execute(query)

colnames = [desc[0] for desc in cursor.description]
rows = cursor.fetchall()

cursor.close()
conn.close()

df = pd.DataFrame(rows, columns=colnames)
df
# Out:
#        protocolo  os_direta
# 0  2005022549532      False
# 1  2009102754325      False

# %%
# Query: Fiscal demanda do usuário 12201
conn = psycopg2.connect(CONN_STRING)
cursor = conn.cursor()

query = """
SELECT fd.* FROM public.fiscaldemanda fd
WHERE fd.usuario_id = 12201 and fd.ativo = true;
"""
cursor.execute(query)

colnames = [desc[0] for desc in cursor.description]
rows = cursor.fetchall()

cursor.close()
conn.close()

df = pd.DataFrame(rows, columns=colnames)
df
# Out:
#           id  ativo               data_criacao usuarioalteracao  usuario_id  \
# 0     419660   True 2018-04-23 11:48:49.787239            12201       12201
# 1    2557416   True 2020-05-12 09:54:16.731000             None       12201
# 2    4420457   True 2022-09-08 09:00:02.318000             None       12201
# 3    5489254   True 2023-06-19 13:06:40.969000             None       12201
# 4    2283246   True 2020-01-20 11:20:55.220000             None       12201
# 5    5488792   True 2023-06-19 13:06:20.918000             None       12201
# 6    5488803   True 2023-06-19 13:06:21.322000             None       12201
# 7    5488814   True 2023-06-19 13:06:21.648000             None       12201
# 8    5488825   True 2023-06-19 13:06:22.230000             None       12201
# 9    5488847   True 2023-06-19 13:06:23.179000             None       12201
# 10   5488858   True 2023-06-19 13:06:24.496000             None       12201
# ...
