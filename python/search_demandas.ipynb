# %%
import psycopg2
import pandas as pd

# String de conexão
conn_string = "postgresql://externo.leitura:WdN#R10gX4@172.31.3.62:5432/fiscalize"

# Conectar ao banco
conn = psycopg2.connect(conn_string)
cursor = conn.cursor()

# Executar query
query = "SELECT * FROM public.demanda WHERE id = 2754325;"
cursor.execute(query)

# Pegar os nomes das colunas
colnames = [desc[0] for desc in cursor.description]

# Pegar os resultados
rows = cursor.fetchall()

# Fechar conexão
cursor.close()
conn.close()

# Criar DataFrame
df = pd.DataFrame(rows, columns=colnames)

# Configurar opções de exibição do pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)

# Exibir o DataFrame com melhor formatação
df
# Out:
#         id  ativo        data_criacao assuntodemanda             bairro  \
# 0  2754325   True 2020-09-10 14:21:00           None  Conjunto Ceará II
#
#   complemento datahoraaberturademanda  datahoraocorrencia  \
# 0        None     2020-09-10 14:21:00 2020-09-10 14:10:00
#
#                                            descricao  enderecoproximidade  \
# 0  Som alto durante toda a semana, principalmente...                False
#
#      latitude logradouro longitude numero pontoreferencia      protocolo  \
# 0  -3.7735758    Rua 735  -38.6041    331          Nenhum  2009102754325
#
#    situacao demanda_id  fiscalizado_id  grupodemanda_id  pessoageradora_id  \
# 0         2       None         2754324            15472            1439029
#
#    regional_id os_id  requeracompanhamento trataranonimamente  plano_id  \
# 0           11  None                 False               None   7480385
#
#   usuarioalteracao autoverificacao demandareferencia situacaoanterior  \
# ...

# %%
import psycopg2
import pandas as pd

# String de conexão
conn_string = "postgresql://externo.leitura:WdN#R10gX4@172.31.3.62:5432/fiscalize"

# Conectar ao banco
conn = psycopg2.connect(conn_string)
cursor = conn.cursor()

# Executar query
query = "SELECT * FROM public.pessoa LIMIT 5;"
cursor.execute(query)

# Pegar os nomes das colunas
colnames = [desc[0] for desc in cursor.description]

# Pegar os resultados
rows = cursor.fetchall()

# Fechar conexão
cursor.close()
conn.close()

# Criar DataFrame
df = pd.DataFrame(rows, columns=colnames)

# Configurar opções de exibição do pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)

# Exibir o DataFrame com melhor formatação
df
# Out:
#         id  ativo            data_criacao            bairro complemento  \
# 0  1872840   True 2019-09-19 09:19:33.346  Carlito Pamplona        None
# 1  1624215   True 2019-07-21 00:17:00.000        JANGURUSSU        None
# 2  2488620   True 2020-03-24 14:03:33.593              None        None
# 3  2488659   True 2020-03-24 14:20:52.597              None        None
# 4  1873114   True 2019-09-19 09:52:00.000     NÃO INFORMADO        None
#
#   contato cpfcnpj   latitude                       logradouro   longitude  \
# 0    None    None  -3.719104     Rua Pedro Clemente Fernandes  -38.550116
# 1    None    None       None  RUA SANTA TEREZINHA DO CONTORNO        None
# 2    None    None       None                             None        None
# 3    None    None       None                             None        None
# 4    None    None       None                                         None
#
#   nomefantasia numero    razaosocial telefone ramoatividade_id  regional_id  \
# ...

# %%
import psycopg2
import pandas as pd

# String de conexão
conn_string = "postgresql://externo.leitura:WdN#R10gX4@172.31.3.62:5432/fiscalize"

# Conectar ao banco
conn = psycopg2.connect(conn_string)
cursor = conn.cursor()

# Executar query com JOIN para filtrar pela situacao da demanda
query = """
SELECT fd.* FROM public.fiscaldemanda fd
JOIN public.demanda d ON fd.demanda_id = d.id
WHERE fd.usuario_id = 12201 and fd.ativo = true and d.ativo = true and d.situacao IN (2, 11, 12);
"""
cursor.execute(query)

# Pegar os nomes das colunas
colnames = [desc[0] for desc in cursor.description]

# Pegar os resultados
rows = cursor.fetchall()

# Fechar conexão
cursor.close()
conn.close()

# Criar DataFrame
df = pd.DataFrame(rows, columns=colnames)

# Configurar opções de exibição do pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)

# Exibir o DataFrame com melhor formatação
df
# Out:
#         id  ativo            data_criacao usuarioalteracao  usuario_id  \
# 0  2557416   True 2020-05-12 09:54:16.731             None       12201
# 1  2877819   True 2020-11-11 13:23:28.636             None       12201
#
#    demanda_id
# 0     2549532
# 1     2754325
